# %% [markdown]
# ## 作業4
# 1. 2p功能與電腦對戰
# 2. 計分功能
# 3. 計算分數與結束遊戲

# %%
import pandas as pd
import numpy as np
import ipywidgets as wg
import os
from IPython.display import clear_output

# %%
def two_player_input():
    input_p1 = input(['玩家 1 請選擇: 剪刀 = 1, 石頭 = 2, 布 = 3'])
    input_p2 = input(['玩家 1 請選擇: 剪刀 = 1, 石頭 = 2, 布 = 3'])
    
    return input_p1, input_p2

# %%
def win_lose_judge(input_1, input_2):
    if input_1 == 1:
        if input_2 == 1:
            return [0,0]
        elif input_2 == 2:
            return [0,1]
        elif input_2 == 3:
            return [1,0]
    elif input_1 == 2:
        if input_2 == 1:
            return[1,0]
        elif input_2 == 2:
            return[0,0]
        elif input_3 == 3:
            return[0,1]
    elif input_1 == 3:
        if input_2 == 1:
            return[0,1]
        elif input_2 == 2:
            return[1,0]
        elif input_2 == 3:
            return[0,0]

# %%
# main
while 1:
    mode_chose = int(input(['請選擇2P或COM : 2P = 1 , COM = 2, 離開 = 0']))
    
    if mode_chose == 0:
        break
    
    round_input = int(input(['請輸入遊玩回數: ']))
    score = [0,0]
    
    for i in range(round_input):
        if mode_chose == 1:
            clear_output()
            print('當前模式: 2P')
            print('選擇遊玩回數 : ' + str(round_input))
            print('目前比數 : ' + str(score[0]) + ' : ' + str(score[1]))
            input_p1, input_p2 = two_player_input()
            win_lose = win_lose_judge(input_p1, input_p2)
        
            if win_lose == [0,0]:
                print('平手!')
            elif win_lose == [1,0]:
                print('玩家 1 勝利!')
                score[0] = score[0] + 1
            elif win_lose == [0,1]:
                print('玩家 2 勝利!')
                score[1] = score[1] + 1
            
        elif mode_chose == 2:
            print('not yet')
# Out:
# 當前模式: 2P
# 選擇遊玩回數 : 3
# 目前比數 : 0 : 0
# ['玩家 1 請選擇: 剪刀 = 1, 石頭 = 2, 布 = 3']1
# ['玩家 1 請選擇: 剪刀 = 1, 石頭 = 2, 布 = 3']2
# ['請選擇2P或COM : 2P = 1 , COM = 2, 離開 = 0']0
